# %%
import pandas as pd

# %%
food = pd.read_csv('../Documents/data/data11/chipotle.tsv', sep='\t')
food
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
food.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
food.shape
# Out:
# (4622, 5)

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
food.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
food.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
food.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
food.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#데이터 전체 기본 통계로 요약
food.describe() #모든 숫자타입을 가지는 피쳐에 대해 기본 통계를 보임.
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
#시리즈의 멤버함수 astype(변경하고 싶은 타입명)
food['order_id'] = food['order_id'].astype(str)
food['order_id'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# Name: order_id, dtype: object

# %%
#데이터 전체 기본 통계로 요약
food.describe()
# Out:
#           quantity
# count  4622.000000
# mean      1.075725
# std       0.410186
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      15.000000

# %%
# 메뉴가 무엇이 있었나?
food['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
# 주문은 몇 개나 있었던 것일까?
len(food['order_id'].unique())
# Out:
# 1834

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

#f_path = "/Users/administrator/Library/Fonts/AppleGothic.ttf"
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
#그룹별로 묶어서 통계를 낼 수는 있으나, 정렬은 해주지 않음.
food.groupby('item_name')['quantity'].sum()
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
type(food_name_gp)
# Out:
# pandas.core.series.Series

# %%
# 가장 많이 주문한 메뉴명 10개?
item_count = food['item_name'].value_counts()
item_count.head(10)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Chips                  211
# Steak Bowl             211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: item_name, dtype: int64

# %%
# Out:
# Chicken Bowl                    726
# Chicken Burrito                 553
# Chips and Guacamole             479
# Steak Burrito                   368
# Canned Soft Drink               301
# Steak Bowl                      211
# Chips                           211
# Bottled Water                   162
# Chicken Soft Tacos              115
# Chips and Fresh Tomato Salsa    110
# Name: item_name, dtype: int64

# %%
type(item_count)  #인덱스객체 + ndarray객체
# Out:
# pandas.core.series.Series

# %%
item_count.index
# Out:
# Index(['Chicken Bowl', 'Chicken Burrito', 'Chips and Guacamole',
#        'Steak Burrito', 'Canned Soft Drink', 'Chips', 'Steak Bowl',
#        'Bottled Water', 'Chicken Soft Tacos', 'Chicken Salad Bowl',
#        'Chips and Fresh Tomato Salsa', 'Canned Soda', 'Side of Chips',
#        'Veggie Burrito', 'Barbacoa Burrito', 'Veggie Bowl', 'Carnitas Bowl',
#        'Barbacoa Bowl', 'Carnitas Burrito', 'Steak Soft Tacos',
#        '6 Pack Soft Drink', 'Chips and Tomatillo Red Chili Salsa',
#        'Chicken Crispy Tacos', 'Chips and Tomatillo Green Chili Salsa',
#        'Carnitas Soft Tacos', 'Steak Crispy Tacos',
#        'Chips and Tomatillo-Green Chili Salsa', 'Steak Salad Bowl',
#        'Nantucket Nectar', 'Barbacoa Soft Tacos',
#        'Chips and Roasted Chili Corn Salsa', 'Izze',
#        'Chips and Tomatillo-Red Chili Salsa',
#        'Chips and Roasted Chili-Corn Salsa', 'Veggie Salad Bowl',
#        'Barbacoa Crispy Tacos', 'Barbacoa Salad Bowl', 'Chicken Salad',
# ...

# %%
item_count.values
# Out:
# array([726, 553, 479, 368, 301, 211, 211, 162, 115, 110, 110, 104, 101,
#         95,  91,  85,  68,  66,  59,  55,  54,  48,  47,  43,  40,  35,
#         31,  29,  27,  25,  22,  20,  20,  18,  18,  11,  10,   9,   7,
#          7,   6,   6,   6,   4,   2,   2,   2,   1,   1,   1], dtype=int64)

# %%
# 많이 팔린 item 10개를 막대 그래프로 그려보자.
item_count = item_count[:10]
plt.figure(figsize=(18,8))
plt.bar(item_count.index, item_count)
# Out:
# <BarContainer object of 10 artists>

# %%
# 순위별로 프린트해보세요.
# TOP 1: Chicken Bowl 726
# item_count
item_count
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Chips                  211
# Steak Bowl             211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: item_name, dtype: int64

# %%
for i in range(len(item_count)):
    print('TOP', i + 1, ':', item_count.index[i], item_count[i])
# Out:
# TOP 1 : Chicken Bowl 726
# TOP 2 : Chicken Burrito 553
# TOP 3 : Chips and Guacamole 479
# TOP 4 : Steak Burrito 368
# TOP 5 : Canned Soft Drink 301
# TOP 6 : Chips 211
# TOP 7 : Steak Bowl 211
# TOP 8 : Bottled Water 162
# TOP 9 : Chicken Soft Tacos 115
# TOP 10 : Chicken Salad Bowl 110

# %%
#lambda로 해결!(찬양씨!)
list(map(lambda x : print("TOP", x+1 ," : ", item_count.index[x], item_count[x]), range(10)))
# Out:
# TOP 1  :  Chicken Bowl 726
# TOP 2  :  Chicken Burrito 553
# TOP 3  :  Chips and Guacamole 479
# TOP 4  :  Steak Burrito 368
# TOP 5  :  Canned Soft Drink 301
# TOP 6  :  Chips 211
# TOP 7  :  Steak Bowl 211
# TOP 8  :  Bottled Water 162
# TOP 9  :  Chicken Soft Tacos 115
# TOP 10  :  Chicken Salad Bowl 110
# [None, None, None, None, None, None, None, None, None, None]

# %%
# enumerate 반복문: index, 반복할 item을 둘 다 꺼내주고 싶을 때 사용
data100 = [100, 200, 300]

for i, item in enumerate(data100, 0): #0은 index의 start값
    print(i, ':', item)
# Out:
# 0 : 100
# 1 : 200
# 2 : 300

# %%
# # 시리즈의 values만 꺼내오고 싶으면, 시리즈를 enumerate에 입력값으로 넣어주면 됨.
# 시리즈를 tolist()하면 시리즈의 values만 리스트로 만들어진다.
item_count.tolist()
# Out:
# [726, 553, 479, 368, 301, 211, 211, 162, 115, 110]

# %%
 #0: index의 start값
    #values만 꺼내온다.
for i,item in enumerate(item_count.tolist(), 0):
    print('TOP', i + 1, ":", item)
# Out:
# TOP 1 : 726
# TOP 2 : 553
# TOP 3 : 479
# TOP 4 : 368
# TOP 5 : 301
# TOP 6 : 211
# TOP 7 : 211
# TOP 8 : 162
# TOP 9 : 115
# TOP 10 : 110

# %%
# enumerate: 열거하다
# Jquery의 $('list').each(): index랑 list의 항목을 하나씩 꺼내는 기능
# item에는 시리즈의 index와 values를 tuple로 반복해서 꺼내온다.
for i, item in enumerate(item_count.iteritems(), 0):
    print('TOP', i + 1, ":", item)
# Out:
# TOP 1 : ('Chicken Bowl', 726)
# TOP 2 : ('Chicken Burrito', 553)
# TOP 3 : ('Chips and Guacamole', 479)
# TOP 4 : ('Steak Burrito', 368)
# TOP 5 : ('Canned Soft Drink', 301)
# TOP 6 : ('Chips', 211)
# TOP 7 : ('Steak Bowl', 211)
# TOP 8 : ('Bottled Water', 162)
# TOP 9 : ('Chicken Soft Tacos', 115)
# TOP 10 : ('Chicken Salad Bowl', 110)

# %%
for i, item in enumerate(item_count.iteritems(), 0):
    print('TOP', i + 1, ":", item[0], item[1])
# Out:
# TOP 1 : Chicken Bowl 726
# TOP 2 : Chicken Burrito 553
# TOP 3 : Chips and Guacamole 479
# TOP 4 : Steak Burrito 368
# TOP 5 : Canned Soft Drink 301
# TOP 6 : Chips 211
# TOP 7 : Steak Bowl 211
# TOP 8 : Bottled Water 162
# TOP 9 : Chicken Soft Tacos 115
# TOP 10 : Chicken Salad Bowl 110

# %%
#  주요 많이 팔린 TOP10까지의 메뉴별 주문 개수

# %%
for i, (index0, index1) in enumerate(item_count.iteritems(), 0):
    print('TOP', i + 1, ':', index0, index1)
# Out:
# TOP 1 : Chicken Bowl 726
# TOP 2 : Chicken Burrito 553
# TOP 3 : Chips and Guacamole 479
# TOP 4 : Steak Burrito 368
# TOP 5 : Canned Soft Drink 301
# TOP 6 : Chips 211
# TOP 7 : Steak Bowl 211
# TOP 8 : Bottled Water 162
# TOP 9 : Chicken Soft Tacos 115
# TOP 10 : Chicken Salad Bowl 110

# %%
# 제일 많이 팔린 메뉴명
item_count.index[0]
# Out:
# 'Chicken Bowl'

# %%
# 제일 많이 팔린 개수
item_count.values[0]
# Out:
# 726

# %%
# item당 주문개수, 주문총량을 구해보세요.
oc = food.groupby('item_name')['order_id'].count()
oc
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
oc2 = food.groupby('item_name')['quantity'].sum()
oc2
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
#전체갯수
sum(oc2)
# Out:
# 4972

# %%
import numpy as np
# 50개를 그려봅시다.!

# X축: 50개의 메뉴명 => 숫자를 부여하자.
x2 = np.arange(50)

# Y축: 메뉴별 판매량
y2 = oc2.values

plt.figure(figsize=(18, 8))
plt.barh(x2, y2, color='springgreen')
plt.title('모든 주문한 메뉴의 판매량')
plt.xlabel('주문한 메뉴의 번호')
plt.ylabel('주문한 메뉴의 판매량')
# Out:
# Text(0,0.5,'주문한 메뉴의 판매량')

# %%
# 50개를 그려봅시다.!

# X축: 50개의 메뉴명 => 숫자를 부여하자.
x2 = np.arange(50) #[0, 1, 2, ...]

# Y축: 메뉴별 판매량
y2 = oc2.values

plt.figure(figsize=(18, 8))
plt.bar(x2, y2, color='gold', edgecolor="gray", linewidth=3)
plt.title('모든 주문한 메뉴의 판매량')
plt.xlabel('주문한 메뉴의 번호')
plt.ylabel('주문한 메뉴의 판매량')
# Out:
# Text(0,0.5,'주문한 메뉴의 판매량')

# %%
order_count3.index[17]
# Out:
# 'Chicken Bowl'

# %%
order_count3.index[26]
# Out:
# 'Chips and Mild Fresh Tomato Salsa'

# %%
food
# Out:
#      order_id  quantity                              item_name  \
# 0           1         1           Chips and Fresh Tomato Salsa
# 1           1         1                                   Izze
# 2           1         1                       Nantucket Nectar
# 3           1         1  Chips and Tomatillo-Green Chili Salsa
# 4           2         2                           Chicken Bowl
# 5           3         1                           Chicken Bowl
# 6           3         1                          Side of Chips
# 7           4         1                          Steak Burrito
# 8           4         1                       Steak Soft Tacos
# 9           5         1                          Steak Burrito
# 10          5         1                    Chips and Guacamole
# 11          6         1                   Chicken Crispy Tacos
# 12          6         1                     Chicken Soft Tacos
# 13          7         1                           Chicken Bowl
# ...

# %%
food['item_price'].dtype #시리즈에 들어있는 인스턴스의 타입
# Out:
# dtype('O')

# %%
food['quantity'].dtype
# Out:
# dtype('int64')

# %%
type(food['item_price']) #열에 대한 타입
# Out:
# pandas.core.series.Series

# %%
food.dtypes
# Out:
# order_id              object
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
food['item_price'][:5]
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %%
#타입변경 방법, 시리즈명.astype(), float()함수 이용

# %%
food['item_price'][4]
# Out:
# '$16.98 '

# %%
type(food['item_price'][4])
# Out:
# str

# %%
food['item_price'][4][1:]
# Out:
# '16.98 '

# %%
float(food['item_price'][4][1:])
# Out:
# 16.98

# %%
#시리즈의 모든 행에 있는 string을 추출해서 $을 빼야한다.(인덱싱을 사용하기로 함.)
#시리즈를 모두 변경하기 위해서는 for문 있어야함.
#float()함수는 비파괴 =>>> float() 캐스팅한 결과를 리스트에 모아놓았다가,
#반복문이 모든 끝나면 리스트에 모아놓은 데이터를 df의 컬럼에 다시 집어넣는다.

# %%
result = []
for price in food['item_price']:
    result.append(float(price[1:]))
result[:10]
# Out:
# [2.39, 3.39, 3.39, 2.39, 16.98, 10.98, 1.69, 11.75, 9.25, 9.25]

# %%
food['item_price'] = result

# %%
food['item_price'][:10].dtype
# Out:
# dtype('float64')

# %%
# Out:
# dtype('float64')

# %%
 #피쳐들 중에서 숫자타입을 가지는 시리즈의 기본 통계
food.describe()
# Out:
#           quantity   item_price
# count  4622.000000  4622.000000
# mean      1.075725     7.464336
# std       0.410186     4.245557
# min       1.000000     1.090000
# 25%       1.000000     3.390000
# 50%       1.000000     8.750000
# 75%       1.000000     9.250000
# max      15.000000    44.250000

# %% [markdown]
# ------------------------------------------------------------------
# ### <Step4. 탐색적 분석> : 스무고개로 분석하는 개념적 탐색
# * 데이터를 이해하기 위한 조금 더 복잡한 질문들로 탐색적 데이터 분석 연습하기
# * 주문당 평균 계산금액 출력하기
# * 한 주문에 10달러 이상 사용한 주문의 id들 출력하기
# * 각 아이템의 가격 구하기
# * 가장 비싼 주문에서 item이 몇개 팔렸는지 구하기
# * "Veggie Salad Bowl"이 몇 번 주문되었는지 구하기
# * "Chicken Bowl"을 2개 이상 주문한 주문 횟수 구하기
# ------------------------------------------------------------------

# %%
food.groupby('order_id')['item_price'].mean()
# Out:
# order_id
# 1        2.890000
# 10       6.600000
# 100      5.040000
# 1000    10.250000
# 1001     5.040000
# 1002     5.340000
# 1003     6.500000
# 1004    21.960000
# 1005     4.050000
# 1006     8.925000
# 1007     3.923333
# 1008     4.050000
# 1009     3.090000
# 101      6.490000
# 1010     8.310000
# 1011     3.250000
# 1012    11.250000
# 1013     7.975000
# 1014     5.040000
# 1015     6.700000
# 1016    10.750000
# 1017    11.250000
# 1018     6.100000
# 1019     7.850000
# 102      4.883333
# 1020     4.883333
# 1021     6.375000
# 1022    10.980000
# 1023    16.980000
# 1024    18.500000
#           ...
# 972      8.750000
# 973      9.380000
# 974      9.000000
# 975      7.833333
# 976      8.166667
# 977      9.985000
# 978      5.116667
# 979      8.316667
# 98       7.433333
# 980      6.335000
# 981     10.500000
# 982      6.850000
# 983      7.820000
# 984      4.983333
# 985     10.980000
# 986      8.750000
# 987     11.500000
# 988      9.985000
# ...

# %% [markdown]
# ### 한 주문에 40달러 이상 사용한 주문의 id들 출력하기

# %%
idPrice = food.groupby('order_id')['item_price'].sum()
idPrice40 = idPrice[idPrice >= 40]
idPrice40
# Out:
# order_id
# 1006     71.40
# 103      47.90
# 1051     59.35
# 1170     44.51
# 1176     43.14
# 1182     42.13
# 1243     43.09
# 1323     40.50
# 1341     44.25
# 1360     52.18
# 1426     44.64
# 1431     41.60
# 1443    160.74
# 1449     95.39
# 1454     85.24
# 1483    139.00
# 1511     41.95
# 1559     82.44
# 1586     51.20
# 1601     42.50
# 1655     49.95
# 1660     70.25
# 1764     55.55
# 1786    114.30
# 1825     66.50
# 195      81.00
# 205     109.90
# 231      45.10
# 343      54.05
# 488      50.90
# 491     102.00
# 511     104.59
# 561      52.45
# 576      46.53
# 577      71.15
# 635      48.45
# 649      41.80
# 688      49.45
# 691     118.25
# 708      41.74
# 737      41.15
# 759      86.30
# 791      45.65
# 806      40.35
# 818      70.85
# 823      41.00
# 848      55.45
# 916      52.45
# 926     205.25
# 949      40.69
# 953      81.14
# 973      46.90
# 996      43.00
# Name: item_price, dtype: float64

# %%
idPrice40.index
# Out:
# Index(['1006', '103', '1051', '1170', '1176', '1182', '1243', '1323', '1341',
#        '1360', '1426', '1431', '1443', '1449', '1454', '1483', '1511', '1559',
#        '1586', '1601', '1655', '1660', '1764', '1786', '1825', '195', '205',
#        '231', '343', '488', '491', '511', '561', '576', '577', '635', '649',
#        '688', '691', '708', '737', '759', '791', '806', '818', '823', '848',
#        '916', '926', '949', '953', '973', '996'],
#       dtype='object', name='order_id')

# %%
len(idPrice40.index)
# Out:
# 53

# %% [markdown]
# ### 각 아이템의 가격 구하기

# %%
len(food.groupby('item_name').min())
# Out:
# 50

# %%
food.groupby('item_name').min()
# Out:
#                                       order_id  quantity  \
# item_name
# 6 Pack Soft Drink                         1076         1
# Barbacoa Bowl                             1000         1
# Barbacoa Burrito                          1002         1
# Barbacoa Crispy Tacos                      110         1
# Barbacoa Salad Bowl                       1283         1
# Barbacoa Soft Tacos                       1103         1
# Bottled Water                             1009         1
# Bowl                                       193         1
# Burrito                                    214         1
# Canned Soda                                100         1
# Canned Soft Drink                         1003         1
# Carnitas Bowl                             1007         1
# Carnitas Burrito                          1003         1
# Carnitas Crispy Tacos                     1559         1
# Carnitas Salad                            1500         1
# ...

# %%
food.groupby('item_name').min()['item_price']
# Out:
# item_name
# 6 Pack Soft Drink                        6.49
# Barbacoa Bowl                            8.69
# Barbacoa Burrito                         8.69
# Barbacoa Crispy Tacos                    8.99
# Barbacoa Salad Bowl                      9.39
# Barbacoa Soft Tacos                      8.99
# Bottled Water                            1.09
# Bowl                                     7.40
# Burrito                                  7.40
# Canned Soda                              1.09
# Canned Soft Drink                        1.25
# Carnitas Bowl                            8.99
# Carnitas Burrito                         8.69
# Carnitas Crispy Tacos                    8.99
# Carnitas Salad                           8.99
# Carnitas Salad Bowl                      9.39
# Carnitas Soft Tacos                      8.99
# Chicken Bowl                             8.19
# Chicken Burrito                          8.19
# Chicken Crispy Tacos                     8.49
# ...

# %%
len(food.groupby('item_name').min()['item_price'])
# Out:
# 50

# %%
len(food['item_name'].unique()) #위에서 구한 메뉴 개수와 비교
# Out:
# 50

# %% [markdown]
# ### 가장 비싼 주문에서 item이 몇개 팔렸는지 구하기

# %%
orderSum = food.groupby('order_id')['item_price'].sum()
orderSum
# Out:
# order_id
# 1       11.56
# 10      13.20
# 100     10.08
# 1000    20.50
# 1001    10.08
# 1002    10.68
# 1003    13.00
# 1004    21.96
# 1005    12.15
# 1006    71.40
# 1007    11.77
# 1008    12.15
# 1009    12.36
# 101     12.98
# 1010    33.24
# 1011    13.00
# 1012    22.50
# 1013    31.90
# 1014    10.08
# 1015    13.40
# 1016    32.25
# 1017    22.50
# 1018    12.20
# 1019    15.70
# 102     14.65
# 1020    14.65
# 1021    12.75
# 1022    10.98
# 1023    16.98
# 1024    18.50
#         ...
# 972     26.25
# 973     46.90
# 974     18.00
# 975     23.50
# 976     24.50
# 977     19.97
# 978     15.35
# 979     24.95
# 98      22.30
# 980     12.67
# 981     21.00
# 982     13.70
# 983     23.46
# 984     14.95
# 985     10.98
# 986     17.50
# 987     23.00
# 988     19.97
# 989     16.95
# 99      13.40
# 990     12.47
# 991     13.40
# 992     13.20
# 993     10.18
# 994     12.67
# 995     24.95
# 996     43.00
# 997     22.50
# 998     10.88
# 999     29.25
# ...

# %%
orderSum[orderSum.values==orderSum.max()]
# Out:
# order_id
# 926    205.25
# Name: item_price, dtype: float64

# %%
a = food.groupby('order_id').sum()['item_price'] == orderSum.max()
food.groupby('order_id').sum()[a]
# Out:
#           quantity  item_price
# order_id
# 926             23      205.25

# %% [markdown]
# ### "Veggie Salad Bowl"이 몇 번 주문되었는지 구하기

# %%
food['item_name'].value_counts()['Veggie Salad Bowl']
# Out:
# 18

# %% [markdown]
# ### "Chicken Bowl"을 2개 이상 주문한 주문 횟수 구하기

# %%
len(food[food['item_name'] == 'Chicken Bowl'][food[food['item_name'] == 'Chicken Bowl']['quantity'] >= 2])
# Out:
# 33

# %%
result2 = food[food['item_name']=='Chicken Bowl']
result2
# Out:
#      order_id  quantity     item_name  \
# 4           2         2  Chicken Bowl
# 5           3         1  Chicken Bowl
# 13          7         1  Chicken Bowl
# 19         10         1  Chicken Bowl
# 26         13         1  Chicken Bowl
# 42         20         1  Chicken Bowl
# 76         34         1  Chicken Bowl
# 78         34         1  Chicken Bowl
# 99         44         1  Chicken Bowl
# 110        49         1  Chicken Bowl
# 123        54         1  Chicken Bowl
# 138        62         1  Chicken Bowl
# 140        63         1  Chicken Bowl
# 142        64         1  Chicken Bowl
# 154        70         2  Chicken Bowl
# 160        73         1  Chicken Bowl
# 176        79         1  Chicken Bowl
# 182        82         1  Chicken Bowl
# 193        86         1  Chicken Bowl
# 199        89         1  Chicken Bowl
# 206        92         1  Chicken Bowl
# 209        93         1  Chicken Bowl
# 211        93         1  Chicken Bowl
# ...

# %%
result2[result2['quantity'] >= 2]['order_id'].count()
# Out:
# 33
