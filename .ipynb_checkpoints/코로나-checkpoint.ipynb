# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
timeDf = pd.read_csv('../covid/Time.csv')
caseDf = pd.read_csv('../covid/Case.csv')
pDf = pd.read_csv('../covid/PatientInfo.csv')

# %%
timeDf.set_index('date', inplace=True)

# %%
tDC = timeDf['confirmed']

plt.rcParams["figure.figsize"] = (20,10)
plt.xlabel('time')
plt.ylabel('cornfirmed')
plt.plot(tDC)
